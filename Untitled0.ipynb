# %% [markdown]
# <a href="https://colab.research.google.com/github/shadabsayyad055/demo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create numpy array

import numpy as np
arr_1=np.array([1,2,3])
print(arr_1)

arr_2=np.array([[4,5,6],[7,8,9]])
print(arr_2)

arr_3=np.array((1,2,3))
print(arr_3)
# Out:
# [1 2 3]
# [[4 5 6]
#  [7 8 9]]
# [1 2 3]

# %%
#Accessing the Array Index

import numpy as np
arr
